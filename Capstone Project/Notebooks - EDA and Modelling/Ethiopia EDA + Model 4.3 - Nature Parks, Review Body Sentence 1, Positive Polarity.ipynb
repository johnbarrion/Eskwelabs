# %%
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline

import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel
import pyLDAvis
import pyLDAvis.gensim  

import spacy
from spacy.lemmatizer import Lemmatizer
from spacy.lang.en.stop_words import STOP_WORDS

from textblob import TextBlob

from tqdm import tqdm_notebook as tqdm
from pprint import pprint
import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\Users\HP\Anaconda3\lib\site-packages\nltk\decorators.py:68: DeprecationWarning: `formatargspec` is deprecated since Python 3.5. Use `signature` and the `Signature` object directly
#   regargs, varargs, varkwargs, defaults, formatvalue=lambda value: ""
# C:\Users\HP\Anaconda3\lib\site-packages\nltk\lm\counter.py:15: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   from collections import Sequence, defaultdict

# %%
df1 = pd.read_csv('ethiopia_tripadvisor_data_model_3.csv')
df1.head()
# Out:
#                  Destination Name Destination Type  \
# 0  Rock-Hewn Churches of Lalibela        Landmarks
# 1  Rock-Hewn Churches of Lalibela        Landmarks
# 2  Rock-Hewn Churches of Lalibela        Landmarks
# 3  Rock-Hewn Churches of Lalibela        Landmarks
# 4  Rock-Hewn Churches of Lalibela        Landmarks
#
#                                          Review Head  \
# 0  Incredible locations don't be put off thinking...
# 1                 It is a real miracle of the world!
# 2                             Incredible experience
# 3                                            Amazing
# 4                                    So much history
#
#                                          Review Body  \
# 0  Amazing location must visit. This site is mark...
# 1  I do recommend to visit Lalibela churches and ...
# 2  A must visit in Ethiopia - one of the most uni...
# 3  These churches have to be seen to be believed....
# 4  Thanks to our tour organiser Ephram who is bas...
#
#                                          Review Text  \
# 0  Incredible locations don't be put off thinking...
# 1  It is a real miracle of the world! I do recomm...
# 2  Incredible experience A must visit in Ethiopia...
# 3  Amazing These churches have to be seen to be b...
# 4  So much history Thanks to our tour organiser E...
#
#                                         RB_Sentence1  TextBlob Polarity Head  \
# 0                       Amazing location must visit.                   -0.05
# 1  I do recommend to visit Lalibela churches and ...                    0.25
# 2  A must visit in Ethiopia - one of the most uni...                    0.90
# 3     These churches have to be seen to be believed.                    0.60
# 4  Thanks to our tour organiser Ephram who is bas...                    0.20
#
#    TextBlob Polarity Body  TextBlob Polarity Text  TextBlob Polarity RBS1  \
# 0                0.300000                0.125000                  0.6000
# 1               -0.150000               -0.016667                  0.0000
# 2                0.345000                0.483750                  0.4375
# 3                0.225000                0.350000                  0.0000
# 4                0.233333                0.228571                  0.2000
#
#                                   RB_Sentence1_Split
# 0          ['Amazing', 'location', 'must', 'visit.']
# 1  ['I', 'do', 'recommend', 'to', 'visit', 'Lalib...
# 2  ['A', 'must', 'visit', 'in', 'Ethiopia', '-', ...
# 3  ['These', 'churches', 'have', 'to', 'be', 'see...
# 4  ['Thanks', 'to', 'our', 'tour', 'organiser', '...

# %%
df1['RH_Split'] = df1['Review Head'].apply(lambda x: x.split(' '))
df1['RB_Split'] = df1['Review Body'].apply(lambda x: x.split(' '))
df1['RT_Split'] = df1['Review Text'].apply(lambda x: x.split(' '))
df1['RB_Sentence1_Split'] = df1['RB_Sentence1'].apply(lambda x: x.split(' '))
df1.head()
# Out:
#                  Destination Name Destination Type  \
# 0  Rock-Hewn Churches of Lalibela        Landmarks
# 1  Rock-Hewn Churches of Lalibela        Landmarks
# 2  Rock-Hewn Churches of Lalibela        Landmarks
# 3  Rock-Hewn Churches of Lalibela        Landmarks
# 4  Rock-Hewn Churches of Lalibela        Landmarks
#
#                                          Review Head  \
# 0  Incredible locations don't be put off thinking...
# 1                 It is a real miracle of the world!
# 2                             Incredible experience
# 3                                            Amazing
# 4                                    So much history
#
#                                          Review Body  \
# 0  Amazing location must visit. This site is mark...
# 1  I do recommend to visit Lalibela churches and ...
# 2  A must visit in Ethiopia - one of the most uni...
# 3  These churches have to be seen to be believed....
# 4  Thanks to our tour organiser Ephram who is bas...
#
#                                          Review Text  \
# 0  Incredible locations don't be put off thinking...
# 1  It is a real miracle of the world! I do recomm...
# 2  Incredible experience A must visit in Ethiopia...
# 3  Amazing These churches have to be seen to be b...
# 4  So much history Thanks to our tour organiser E...
#
#                                         RB_Sentence1  TextBlob Polarity Head  \
# 0                       Amazing location must visit.                   -0.05
# 1  I do recommend to visit Lalibela churches and ...                    0.25
# 2  A must visit in Ethiopia - one of the most uni...                    0.90
# 3     These churches have to be seen to be believed.                    0.60
# 4  Thanks to our tour organiser Ephram who is bas...                    0.20
#
#    TextBlob Polarity Body  TextBlob Polarity Text  TextBlob Polarity RBS1  \
# 0                0.300000                0.125000                  0.6000
# 1               -0.150000               -0.016667                  0.0000
# 2                0.345000                0.483750                  0.4375
# 3                0.225000                0.350000                  0.0000
# 4                0.233333                0.228571                  0.2000
#
#                                   RB_Sentence1_Split  \
# 0                  [Amazing, location, must, visit.]
# 1  [I, do, recommend, to, visit, Lalibela, church...
# 2  [A, must, visit, in, Ethiopia, -, one, of, the...
# 3  [These, churches, have, to, be, seen, to, be, ...
# 4  [Thanks, to, our, tour, organiser, Ephram, who...
#
#                                             RH_Split  \
# 0  [Incredible, locations, don't, be, put, off, t...
# 1        [It, is, a, real, miracle, of, the, world!]
# 2                         [Incredible, experience, ]
# 3                                          [Amazing]
# 4                                [So, much, history]
#
#                                             RB_Split  \
# 0  [Amazing, location, must, visit., This, site, ...
# 1  [I, do, recommend, to, visit, Lalibela, church...
# 2  [A, must, visit, in, Ethiopia, -, one, of, the...
# 3  [These, churches, have, to, be, seen, to, be, ...
# 4  [Thanks, to, our, tour, organiser, Ephram, who...
#
#                                             RT_Split
# 0  [Incredible, locations, don't, be, put, off, t...
# 1  [It, is, a, real, miracle, of, the, world!, I,...
# 2  [Incredible, experience, A, must, visit, in, E...
# 3  [Amazing, These, churches, have, to, be, seen,...
# 4  [So, much, history, Thanks, to, our, tour, org...

# %%
df1['Destination Type'].value_counts()
# Out:
# Landmarks       3803
# Museums         2507
# Nature/Parks    2001
# Name: Destination Type, dtype: int64

# %% [markdown]
# ### Topic Modelling

# %%
# NLTK Stop words
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

test_subset = df1['RB_Sentence1_Split'].values
sid = SentimentIntensityAnalyzer()
pos_word_list=[]
neu_word_list=[]
neg_word_list=[]

for value in test_subset:
    for word in value:
        if (sid.polarity_scores(word)['compound']) >= 0.4:
            pos_word_list.append(word)
        elif (sid.polarity_scores(word)['compound']) <= -0.4:
            print
            neg_word_list.append(word)
        else:
            neu_word_list.append(word)                

print('Positive :', len(pos_word_list))       
print('Neutral :', len(neu_word_list))    
print('Negative :', len(neg_word_list))
# Out:
# Positive : 5775
# Neutral : 133685
# Negative : 748

# %%
from nltk.corpus import stopwords

main_stop_words = ['ethiopia', 'ethiopian', 'rock', 'hewn', 'church', 'churches', 'park', 'parks', 'museum', 
                       'museums', 'omo', 'valley', 'mountain', 'mountains', 'addis', 'ababa', 'lucy', 'simien', 
                       'national', 'lalibela', 'gelada', 'haile', 'selassie', 'gondar', 'africa' , 'harar', 
                       'cathedral', 'cathedrals', 'place', 'visit', 'girmay', 
                       '\n', '‘s']
positive_stop_words = list(set(pos_word_list))
negative_stop_words = list(set(neg_word_list))
total_stop_words = main_stop_words + positive_stop_words + negative_stop_words

stop_words = stopwords.words('english')
stop_words.extend(['from', 'subject', 're', 'edu', 'use'])
stop_words.extend(total_stop_words)
print('Stop Words: ', len(stop_words))
# Out:
# Stop Words:  1148

# %%
# Convert to list
data = df1[df1['Destination Type'] == 'Nature/Parks'][df1['TextBlob Polarity RBS1'] > 0]['RB_Sentence1'].values.tolist()

# Remove Emails
data = [re.sub('\S*@\S*\s?', '', sent) for sent in data]

# Remove new line characters
data = [re.sub('\s+', ' ', sent) for sent in data]

# Remove distracting single quotes
data = [re.sub("\'", "", sent) for sent in data]

pprint(data[:1])
# Out:
# ['I had the most amazing experience in the incredible Simien Mountains '
#  'trekking with Afera from Panoramic Simiens.']

# %%
def sent_to_words(sentences):
    for sentence in sentences:
        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))  # deacc=True removes punctuations

data_words = list(sent_to_words(data))

print(data_words[:1])
# Out:
# [['had', 'the', 'most', 'amazing', 'experience', 'in', 'the', 'incredible', 'simien', 'mountains', 'trekking', 'with', 'afera', 'from', 'panoramic', 'simiens']]

# %%
# Build the bigram and trigram models
bigram = gensim.models.Phrases(data_words, min_count=5, threshold=100) # higher threshold fewer phrases.
trigram = gensim.models.Phrases(bigram[data_words], threshold=100)  

# Faster way to get a sentence clubbed as a trigram/bigram
bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

# See trigram example
print(trigram_mod[bigram_mod[data_words[0]]])
# Out:
# ['had', 'the', 'most', 'amazing', 'experience', 'in', 'the', 'incredible', 'simien', 'mountains', 'trekking', 'with', 'afera', 'from', 'panoramic', 'simiens']

# %%
# Define functions for stopwords, bigrams, trigrams and lemmatization
def remove_stopwords(texts):
    return [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]

def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

def make_trigrams(texts):
    return [trigram_mod[bigram_mod[doc]] for doc in texts]

def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    """https://spacy.io/api/annotation"""
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
    return texts_out

# %%
# Remove Stop Words
data_words_nostops = remove_stopwords(data_words)

# Form Bigrams
data_words_bigrams = make_bigrams(data_words_nostops)

# Initialize spacy 'en' model, keeping only tagger component (for efficiency)
# python3 -m spacy download en
nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])

# Do lemmatization keeping only noun, adj, vb, adv
data_lemmatized = lemmatization(data_words_bigrams, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])

print(data_lemmatized[:1])
# Out:
# [['experience', 'incredible', 'trek', 'panoramic', 'simien']]

# %%
# Create Dictionary
id2word = corpora.Dictionary(data_lemmatized)

# Create Corpus
texts = data_lemmatized

# Term Document Frequency
corpus = [id2word.doc2bow(text) for text in texts]

# View
print(corpus[:1])
# Out:
# [[(0, 1), (1, 1), (2, 1), (3, 1), (4, 1)]]

# %%
# Human readable format of corpus (term-frequency)
[[(id2word[id], freq) for id, freq in cp] for cp in corpus[:1]]
# Out:
# [[('experience', 1),
#   ('incredible', 1),
#   ('panoramic', 1),
#   ('simien', 1),
#   ('trek', 1)]]

# %%
# Build LDA model
lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus,
                                           id2word=id2word,
                                           num_topics=10, 
                                           random_state=100,
                                           update_every=1,
                                           chunksize=100,
                                           passes=10,
                                           alpha='auto',
                                           per_word_topics=True)

# %%
# Print the Keyword in the n topics
pprint(lda_model.print_topics())
doc_lda = lda_model[corpus]
# Out:
# [(0,
#   '0.092*"view" + 0.055*"scenery" + 0.048*"spectacular" + 0.040*"landscape" + '
#   '0.034*"road" + 0.031*"worth" + 0.029*"stunning" + 0.029*"wildlife" + '
#   '0.020*"offer" + 0.018*"company"'),
#  (1,
#   '0.117*"see" + 0.044*"incredible" + 0.044*"hippos" + 0.039*"year" + '
#   '0.037*"organise" + 0.029*"include" + 0.027*"drive" + 0.027*"crocodile" + '
#   '0.023*"professional" + 0.023*"bird"'),
#  (2,
#   '0.112*"experience" + 0.048*"people" + 0.036*"make" + 0.035*"find" + '
#   '0.031*"unforgettable" + 0.031*"hike" + 0.023*"part" + 0.023*"go" + '
#   '0.021*"say" + 0.021*"magic"'),
#  (3,
#   '0.124*"time" + 0.054*"walk" + 0.053*"tribe" + 0.040*"local" + 0.039*"long" '
#   '+ 0.024*"much" + 0.023*"different" + 0.022*"cultural" + 0.019*"tourist" + '
#   '0.018*"recent"'),
#  (4,
#   '0.064*"get" + 0.048*"close" + 0.047*"absolutely" + 0.044*"well" + '
#   '0.043*"many" + 0.042*"baboon" + 0.034*"arrange" + 0.024*"plan" + '
#   '0.023*"use" + 0.023*"full"'),
#  (5,
#   '0.071*"area" + 0.053*"want" + 0.041*"do" + 0.040*"start" + '
#   '0.034*"destination" + 0.026*"organize" + 0.020*"comment" + 0.020*"internet" '
#   '+ 0.019*"fish" + 0.019*"colour"'),
#  (6,
#   '0.172*"tour" + 0.126*"guide" + 0.069*"take" + 0.023*"boat" + 0.023*"give" + '
#   '0.022*"enough" + 0.021*"city" + 0.020*"book" + 0.015*"rate" + '
#   '0.014*"fisherman"'),
#  (7,
#   '0.085*"spend" + 0.060*"travel" + 0.058*"go" + 0.058*"first" + 0.057*"week" '
#   '+ 0.034*"lot" + 0.031*"have" + 0.030*"other" + 0.022*"animal" + '
#   '0.019*"tell"'),
#  (8,
#   '0.084*"really" + 0.048*"recommend" + 0.042*"natural" + 0.033*"simien" + '
#   '0.026*"highly" + 0.024*"look" + 0.021*"authentic" + 0.020*"nature" + '
#   '0.018*"adventure" + 0.018*"highlight"'),
#  (9,
#   '0.229*"day" + 0.135*"trip" + 0.104*"trek" + 0.048*"visit" + 0.044*"night" + '
#   '0.024*"also" + 0.024*"ever" + 0.019*"know" + 0.015*"highly_recommend" + '
#   '0.012*"highest_peak"')]

# %%
# Compute Perplexity
print('\nPerplexity: ', lda_model.log_perplexity(corpus))  # a measure of how good the model is. lower the better.

# Compute Coherence Score
coherence_model_lda = CoherenceModel(model=lda_model, texts=data_lemmatized, dictionary=id2word, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)
# Out:
# Perplexity:  -7.058277628546564
#
# Coherence Score:  0.5555558495646391

# %%
# Visualize the topics
# pyLDAvis.enable_notebook()
# vis = pyLDAvis.gensim.prepare(lda_model, corpus, id2word)
# vis

# %%
# Download File: http://mallet.cs.umass.edu/dist/mallet-2.0.8.zip
import os
os.environ.update({'MALLET_HOME':r'C:/Users/HP/mallet-2.0.8/'})
mallet_path = r'C:\Users\HP\mallet-2.0.8\bin\mallet' # update this path
ldamallet = gensim.models.wrappers.LdaMallet(mallet_path, corpus=corpus, num_topics=10, id2word=id2word)

# %%
# Show Topics
pprint(ldamallet.show_topics(formatted=False))

# Compute Coherence Score
coherence_model_ldamallet = CoherenceModel(model=ldamallet, texts=data_lemmatized, dictionary=id2word, coherence='c_v')
coherence_ldamallet = coherence_model_ldamallet.get_coherence()
print('\nCoherence Score: ', coherence_ldamallet)
# Out:
# [(0,
#   [('view', 0.13052208835341367),
#    ('landscape', 0.0823293172690763),
#    ('spectacular', 0.07429718875502007),
#    ('animal', 0.04819277108433735),
#    ('high', 0.03815261044176707),
#    ('road', 0.02208835341365462),
#    ('large', 0.02208835341365462),
#    ('range', 0.020080321285140562),
#    ('hippos', 0.01606425702811245),
#    ('bird', 0.01606425702811245)]),
#  (1,
#   [('time', 0.16727272727272727),
#    ('visit', 0.11272727272727273),
#    ('tribe', 0.08545454545454545),
#    ('worth', 0.04181818181818182),
#    ('book', 0.03272727272727273),
#    ('live', 0.02909090909090909),
#    ('long', 0.025454545454545455),
#    ('driver', 0.02181818181818182),
#    ('adventure', 0.02181818181818182),
#    ('southern', 0.02)]),
#  (2,
#   [('scenery', 0.08133086876155268),
#    ('walk', 0.06284658040665435),
#    ('area', 0.06099815157116451),
#    ('baboon', 0.04621072088724584),
#    ('stunning', 0.04621072088724584),
#    ('include', 0.04251386321626617),
#    ('place', 0.04066543438077634),
#    ('group', 0.03512014787430684),
#    ('world', 0.029574861367837338),
#    ('natural', 0.027726432532347505)]),
#  (3,
#   [('experience', 0.22727272727272727),
#    ('organize', 0.045454545454545456),
#    ('spend', 0.041501976284584984),
#    ('year', 0.039525691699604744),
#    ('close', 0.037549407114624504),
#    ('tourist', 0.021739130434782608),
#    ('boat', 0.019762845849802372),
#    ('drive', 0.019762845849802372),
#    ('small', 0.015810276679841896),
#    ('view', 0.015810276679841896)]),
#  (4,
#   [('day', 0.302504816955684),
#    ('wildlife', 0.05394990366088632),
#    ('absolutely', 0.05009633911368015),
#    ('unique', 0.038535645472061654),
#    ('lot', 0.036608863198458574),
#    ('unforgettable', 0.036608863198458574),
#    ('site', 0.02697495183044316),
#    ('wolf', 0.02119460500963391),
#    ('bird', 0.019267822736030827),
#    ('town', 0.017341040462427744)]),
#  (5,
#   [('day', 0.1984732824427481),
#    ('trek', 0.17748091603053434),
#    ('night', 0.1297709923664122),
#    ('simien', 0.05343511450381679),
#    ('monkey', 0.03435114503816794),
#    ('stay', 0.03435114503816794),
#    ('expect', 0.030534351145038167),
#    ('family', 0.026717557251908396),
#    ('explore', 0.02099236641221374),
#    ('knowledge', 0.009541984732824428)]),
#  (6,
#   [('trip', 0.29357798165137616),
#    ('spend', 0.07522935779816514),
#    ('week', 0.062385321100917435),
#    ('part', 0.04220183486238532),
#    ('return', 0.03669724770642202),
#    ('northern', 0.025688073394495414),
#    ('give', 0.023853211009174313),
#    ('arrange', 0.023853211009174313),
#    ('region', 0.022018348623853212),
#    ('crocodile', 0.02018348623853211)]),
#  (7,
#   [('guide', 0.20943396226415095),
#    ('local', 0.06415094339622641),
#    ('incredible', 0.062264150943396226),
#    ('make', 0.052830188679245285),
#    ('find', 0.045283018867924525),
#    ('spend', 0.020754716981132074),
#    ('short', 0.016981132075471698),
#    ('hour', 0.016981132075471698),
#    ('rare', 0.01509433962264151),
#    ('camping', 0.01509433962264151)]),
#  (8,
#   [('people', 0.07945736434108527),
#    ('nature', 0.04263565891472868),
#    ('meet', 0.03294573643410853),
#    ('life', 0.031007751937984496),
#    ('company', 0.029069767441860465),
#    ('team', 0.027131782945736434),
#    ('early', 0.025193798449612403),
#    ('top', 0.023255813953488372),
#    ('show', 0.02131782945736434),
#    ('feel', 0.02131782945736434)]),
#  (9,
#   [('tour', 0.22887323943661972),
#    ('travel', 0.0897887323943662),
#    ('recommend', 0.06690140845070422),
#    ('hike', 0.04929577464788732),
#    ('organise', 0.03873239436619718),
#    ('start', 0.035211267605633804),
#    ('bale', 0.02112676056338028),
#    ('contact', 0.01936619718309859),
#    ('real', 0.017605633802816902),
#    ('complete', 0.01584507042253521)])]
#
# Coherence Score:  0.6123159714440033

# %%
def compute_coherence_values(dictionary, corpus, texts, limit, start, step):
    """
    Compute c_v coherence for various number of topics

    Parameters:
    ----------
    dictionary : Gensim dictionary
    corpus : Gensim corpus
    texts : List of input texts
    limit : Max num of topics

    Returns:
    -------
    model_list : List of LDA topic models
    coherence_values : Coherence values corresponding to the LDA model with respective number of topics
    """
    coherence_values = []
    model_list = []
    for num_topics in range(start, limit, step):
        model = gensim.models.wrappers.LdaMallet(mallet_path, corpus=corpus, num_topics=num_topics, id2word=id2word)
        model_list.append(model)
        coherencemodel = CoherenceModel(model=model, texts=texts, dictionary=dictionary, coherence='c_v')
        coherence_values.append(coherencemodel.get_coherence())

    return model_list, coherence_values

start1 = 2 
limit1 = 11
step1 = 1

model_list, coherence_values = compute_coherence_values(dictionary=id2word, corpus=corpus, texts=data_lemmatized, start=start1, limit=limit1, step=step1)

x = range(start1, limit1, step1)
plt.plot(x, coherence_values)
plt.xlabel("Num Topics")
plt.ylabel("Coherence score")
plt.legend(("coherence_values"), loc='best')
plt.show()

# %%
# Print the coherence scores
for m, cv in zip(x, coherence_values):
    print("Num Topics =", m, " has Coherence Value of", round(cv, 4))
# Out:
# Num Topics = 2  has Coherence Value of 0.381
# Num Topics = 3  has Coherence Value of 0.4584
# Num Topics = 4  has Coherence Value of 0.5046
# Num Topics = 5  has Coherence Value of 0.5433
# Num Topics = 6  has Coherence Value of 0.5923
# Num Topics = 7  has Coherence Value of 0.5673
# Num Topics = 8  has Coherence Value of 0.6125
# Num Topics = 9  has Coherence Value of 0.6276
# Num Topics = 10  has Coherence Value of 0.6104

# %%
# optimal_model = model_list[7] # Number of Topics = 9

optimal_model = gensim.models.wrappers.LdaMallet(mallet_path, corpus=corpus, num_topics=9, id2word=id2word)
model_topics = optimal_model.show_topics(formatted=False)
pprint(optimal_model.print_topics(num_words=10))
# Out:
# [(0,
#   '0.265*"trip" + 0.053*"area" + 0.048*"make" + 0.041*"find" + 0.039*"part" + '
#   '0.036*"organize" + 0.031*"guide" + 0.026*"highlight" + 0.024*"arrange" + '
#   '0.021*"adventure"'),
#  (1,
#   '0.149*"guide" + 0.109*"night" + 0.070*"scenery" + 0.045*"hike" + '
#   '0.045*"simien" + 0.040*"day" + 0.037*"include" + 0.029*"stay" + '
#   '0.027*"bird" + 0.026*"expect"'),
#  (2,
#   '0.193*"experience" + 0.093*"travel" + 0.061*"local" + 0.039*"place" + '
#   '0.034*"unforgettable" + 0.034*"group" + 0.030*"bale" + 0.027*"natural" + '
#   '0.025*"culture" + 0.020*"large"'),
#  (3,
#   '0.110*"visit" + 0.083*"tribe" + 0.039*"organise" + 0.039*"landscape" + '
#   '0.028*"live" + 0.028*"world" + 0.025*"life" + 0.023*"give" + '
#   '0.019*"crocodile" + 0.019*"southern"'),
#  (4,
#   '0.392*"day" + 0.118*"spend" + 0.061*"spectacular" + 0.034*"start" + '
#   '0.016*"thing" + 0.015*"boat" + 0.013*"hour" + 0.013*"short" + 0.013*"half" '
#   '+ 0.010*"reach"'),
#  (5,
#   '0.168*"trek" + 0.094*"view" + 0.058*"walk" + 0.048*"wildlife" + '
#   '0.039*"animal" + 0.038*"nature" + 0.021*"camp" + 0.019*"feel" + '
#   '0.019*"show" + 0.019*"full"'),
#  (6,
#   '0.214*"tour" + 0.043*"absolutely" + 0.031*"high" + 0.031*"landscape" + '
#   '0.030*"monkey" + 0.030*"book" + 0.030*"view" + 0.025*"company" + '
#   '0.023*"wild" + 0.023*"driver"'),
#  (7,
#   '0.071*"people" + 0.057*"week" + 0.055*"incredible" + 0.034*"unique" + '
#   '0.033*"lot" + 0.031*"region" + 0.029*"return" + 0.024*"site" + 0.024*"team" '
#   '+ 0.019*"long"'),
#  (8,
#   '0.155*"time" + 0.060*"recommend" + 0.047*"baboon" + 0.043*"stunning" + '
#   '0.034*"year" + 0.031*"close" + 0.026*"meet" + 0.024*"top" + 0.021*"hippos" '
#   '+ 0.016*"back"')]

# %%
def format_topics_sentences(ldamodel=lda_model, corpus=corpus, texts=data):
    # Init output
    sent_topics_df = pd.DataFrame()

    # Get main topic in each document
    for i, row in enumerate(ldamodel[corpus]):
        row = sorted(row, key=lambda x: (x[1]), reverse=True)
        # Get the Dominant topic, Perc Contribution and Keywords for each document
        for j, (topic_num, prop_topic) in enumerate(row):
            if j == 0:  # => dominant topic
                wp = ldamodel.show_topic(topic_num)
                topic_keywords = ", ".join([word for word, prop in wp])
                sent_topics_df = sent_topics_df.append(pd.Series([int(topic_num), round(prop_topic,4), topic_keywords]), ignore_index=True)
            else:
                break
    sent_topics_df.columns = ['Dominant_Topic', 'Perc_Contribution', 'Topic_Keywords']

    # Add original text to the end of the output
    contents = pd.Series(texts)
    sent_topics_df = pd.concat([sent_topics_df, contents], axis=1)
    return(sent_topics_df)


df_topic_sents_keywords = format_topics_sentences(ldamodel=optimal_model, corpus=corpus, texts=data)

# Format
df_dominant_topic = df_topic_sents_keywords.reset_index()
df_dominant_topic.columns = ['Document_No', 'Dominant_Topic', 'Topic_Perc_Contrib', 'Keywords', 'Text']

# Show
df_dominant_topic.head(10)
# Out:
#    Document_No  Dominant_Topic  Topic_Perc_Contrib  \
# 0            0             5.0              0.1374
# 1            1             6.0              0.1528
# 2            2             3.0              0.1285
# 3            3             1.0              0.1218
# 4            4             1.0              0.1475
# 5            5             1.0              0.1261
# 6            6             8.0              0.1399
# 7            7             1.0              0.1303
# 8            8             2.0              0.1261
# 9            9             3.0              0.1733
#
#                                             Keywords  \
# 0  trek, view, walk, wildlife, animal, nature, ca...
# 1  tour, absolutely, high, landscape, monkey, boo...
# 2  visit, tribe, organise, landscape, live, world...
# 3  guide, night, scenery, hike, simien, day, incl...
# 4  guide, night, scenery, hike, simien, day, incl...
# 5  guide, night, scenery, hike, simien, day, incl...
# 6  time, recommend, baboon, stunning, year, close...
# 7  guide, night, scenery, hike, simien, day, incl...
# 8  experience, travel, local, place, unforgettabl...
# 9  visit, tribe, organise, landscape, live, world...
#
#                                                 Text
# 0  I had the most amazing experience in the incre...
# 1  Its been a splendor and amazing experience fro...
# 2  Excellent trek in Simien - well organised by D...
# 3                Simien Mountains offer great views.
# 4  Majestic scenery, testing terrain at times so ...
# 5  The 7-day trek took us through exquisite scene...
# 6  Coming from France ,I have visited Ethiopia fo...
# 7  We went to the Simien Mountains in the first d...
# 8  Omo Valley seemed to me as a unique place in E...
# 9  The magnicifent Omo Valley, located in East Af...

# %%
df_dominant_topic['Dominant_Topic'].value_counts()
# Out:
# 0.0    268
# 1.0    143
# 2.0    135
# 4.0    131
# 5.0    128
# 6.0    122
# 3.0    113
# 7.0     97
# 8.0     89
# Name: Dominant_Topic, dtype: int64

# %%
# df_dominant_topic[df_dominant_topic['Dominant_Topic'] == 0]['Text'].values # Trekking/Hiking Experience - 268
# df_dominant_topic[df_dominant_topic['Dominant_Topic'] == 1]['Text'].values # Visual (Aesthetic, Scenery, etc.) - 143
# df_dominant_topic[df_dominant_topic['Dominant_Topic'] == 2]['Text'].values # General Appreciation - 135
# df_dominant_topic[df_dominant_topic['Dominant_Topic'] == 3]['Text'].values # General Appreciation - 113
# df_dominant_topic[df_dominant_topic['Dominant_Topic'] == 4]['Text'].values # General Appreciation - 131
# df_dominant_topic[df_dominant_topic['Dominant_Topic'] == 5]['Text'].values # Trekking/Hiking Experience - 128
# df_dominant_topic[df_dominant_topic['Dominant_Topic'] == 6]['Text'].values # General Appreciation - 122
# df_dominant_topic[df_dominant_topic['Dominant_Topic'] == 7]['Text'].values # Tour Guide - 97
# df_dominant_topic[df_dominant_topic['Dominant_Topic'] == 8]['Text'].values # Visual (Aesthetic, Scenery, etc.) - 89

# %%
# Group top 5 sentences under each topic
sent_topics_sorteddf_mallet = pd.DataFrame()

sent_topics_outdf_grpd = df_topic_sents_keywords.groupby('Dominant_Topic')

for i, grp in sent_topics_outdf_grpd:
    sent_topics_sorteddf_mallet = pd.concat([sent_topics_sorteddf_mallet, 
                                             grp.sort_values(['Perc_Contribution'], ascending=[0]).head(1)], 
                                            axis=0)

# Reset Index    
sent_topics_sorteddf_mallet.reset_index(drop=True, inplace=True)

# Format
sent_topics_sorteddf_mallet.columns = ['Topic_Num', "Topic_Perc_Contrib", "Keywords", "Text"]

# Show
sent_topics_sorteddf_mallet.head(10)
# Out:
#    Topic_Num  Topic_Perc_Contrib  \
# 0        0.0              0.1726
# 1        1.0              0.2183
# 2        2.0              0.1910
# 3        3.0              0.1880
# 4        4.0              0.1717
# 5        5.0              0.1697
# 6        6.0              0.1902
# 7        7.0              0.1832
# 8        8.0              0.1907
#
#                                             Keywords  \
# 0  trip, area, make, find, part, organize, guide,...
# 1  guide, night, scenery, hike, simien, day, incl...
# 2  experience, travel, local, place, unforgettabl...
# 3  visit, tribe, organise, landscape, live, world...
# 4  day, spend, spectacular, start, thing, boat, h...
# 5  trek, view, walk, wildlife, animal, nature, ca...
# 6  tour, absolutely, high, landscape, monkey, boo...
# 7  people, week, incredible, unique, lot, region,...
# 8  time, recommend, baboon, stunning, year, close...
#
#                                                 Text
# 0  Our guide Birku Tesfaw organized our trip to S...
# 1  Great hike in the Simiens although more diffic...
# 2  If you looking for a cheap but awesome experie...
# 3  around the omo national park there are many tr...
# 4  This park has many different grades for hiking...
# 5  The park is not very large and surprisingly yo...
# 6  In January 2017 I went on a 12 day photo tour ...
# 7  We have recently returned from an incredible 5...
# 8  Forest looks like a bunch of broccoli when you...

# %%
sent_topics_sorteddf_mallet['Text'].values
# Out:
# array(['Our guide Birku Tesfaw organized our trip to Simien mountains and to other parts of Etiopia, if anybody want to have good guide call him.',
#        'Great hike in the Simiens although more difficult than expected and extremely cold camping at night.',
#        'If you looking for a cheap but awesome experience around the Omo valley tribes, check Baby Jinka, he knows the surrounding as he is local, he took us very nice places with minibus and very experience driver, very reasonable price for backpackers with limited budget,...',
#        'around the omo national park there are many tribes who lives with different costumes culture and thise tribes like mursi, dassanech/geleb/ are so wild in their life they are bared body ,they have nothing to wear because of their culture and they put clay or...',
#        'This park has many different grades for hiking from half a day to several days.',
#        'The park is not very large and surprisingly you can actually view animals walking in the park.',
#        'In January 2017 I went on a 12 day photo tour with Epic Photo Tours whose ground operator was SORA Tours,who is based in Addis Abba.',
#        'We have recently returned from an incredible 5-week trip to Ethiopia which included two weeks in the south with our guide, Lalo Desse.',
#        'Forest looks like a bunch of broccoli when you look at it from the top (from the Paradise Lodge) We had an amazing time visiting the surrounding forest around the 40 springs which were the main attractions but not the springs themselves since it was...'],
#       dtype=object)

# %%
# # Number of Documents for Each Topic
# topic_counts = df_topic_sents_keywords['Dominant_Topic'].value_counts()

# # Percentage of Documents for Each Topic
# topic_contribution = round(topic_counts/topic_counts.sum(), 4)

# # Topic Number and Keywords
# topic_num_keywords = df_topic_sents_keywords[['Dominant_Topic', 'Topic_Keywords']]

# # Concatenate Column wise
# df_dominant_topics = pd.concat([topic_num_keywords, topic_counts, topic_contribution], axis=1)

# # Change Column names
# df_dominant_topics.columns = ['Dominant_Topic', 'Topic_Keywords', 'Num_Documents', 'Perc_Documents']

# # Show
# df_dominant_topics
